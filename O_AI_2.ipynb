# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install openai==1.0.0
# Out:
# Requirement already satisfied: openai==1.0.0 in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.0.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.0.0) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.0.0) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.0.0) (2.6.4)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.0.0) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai==1.0.0) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.0.0) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.0.0) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai==1.0.0) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.0.0) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.0.0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.0.0) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.0.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.0.0) (2.16.3)

# %%
! pip install load_dotenv
# Out:
# Requirement already satisfied: load_dotenv in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from load_dotenv) (1.0.1)

# %%
import openai
import os

from dotenv import load_dotenv
OPENAI_API_KEY = "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"

# Load the environment variables
load_dotenv()

# Set the OpenAI API key
openai.api_key = os.getenv('OPENAI_API_KEY')

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
road_safety = """
When to stop a car:
1.If the speed is above 50km/hr then instruct the car to stop else no instructions.
2.When there is animals or pedestrians crossing the road, the instruct the car to stop.
3.If there is a speed breaker ahead, then stop the car.

When to give instruction to slow down the car:
1.When there is a pothole ahead.
2.When the weather conditions are very extreme like there is fog, mist etc.
3.When there is multiple spead breaker.
4. There is traffic speed signal board specifying the speed the slow down the car according to the speed .
"""

# %%
prompt = f"""
Your task is to direct and give instructions to a driver to as there is a speed breaker approaching ahead.

Write a description based on the information
provided only by not providing extra information in the technical specifications delimited by
triple backticks.

Use at most 30 words.

Technical specifications: ```{road_safety}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Approaching speed breaker ahead, slow down the car.

# %%
prompt = f"""
Your task is to direct and give instructions to a driver to as there is a dog crossing the road ahead.

Write a description based on the information
provided only by not providing extra information in the technical specifications delimited by
triple backticks.

Use at most 20 words.

Technical specifications: ```{road_safety}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Driver, stop the car! A dog is crossing the road ahead.

# %%
! pip install gtts
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.10/dist-packages (2.5.1)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.7.22)

# %%
! pip install gtts pydub
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.10/dist-packages (2.5.1)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from gtts) (2.31.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gtts) (8.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->gtts) (2023.7.22)

# %%
! pip install playsound
# Out:
# Requirement already satisfied: playsound in /usr/local/lib/python3.10/dist-packages (1.3.0)

# %%
# Out:
# Mounted at /content/drive

# %%
from gtts import gTTS
import os

language = 'en'


# Create a text-to-speech object
tts = gTTS(text=response, lang=language, slow=False)

# Save the audio output to a file
tts.save("output.mp3")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3600cc2df678> in <cell line: 8>()
#       6
#       7 # Create a text-to-speech object
# ----> 8 tts = gTTS(text=response, lang=language, slow=False)
#       9
#      10 # Save the audio output to a file
#
# NameError: name 'response' is not defined

# %%
from gtts import gTTS
import io
from io import BytesIO
responses = 'Please drive the car safely'
mp3_fp = BytesIO()
tts = gTTS(responses, lang='en')
tts.write_to_fp(mp3_fp)

# %%
! pip install roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="qScbRsjfKz4rGJXPM164")
project = rf.workspace().project("smart-driver-assistant-6mw78")
model = project.version(3).model


job_id, signed_url, _ = model.predict_video(
    "harsh_road.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL",signed_url)
results = model.poll_until_video_results(job_id)

print("Results",results)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/roboflow/models/inference.py in predict_video(self, video_path, fps, additional_models, prediction_type)
#     221             try:
# --> 222                 with open(video_path, "rb") as f:
#     223                     video_data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'harsh_road.mp4'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-38-4220bf4d5aa2> in <cell line: 8>()
#       6
#       7
# ----> 8 job_id, signed_url, _ = model.predict_video(
#       9     "harsh_road.mp4",
#      10     fps=5,
#
# /usr/local/lib/python3.10/dist-packages/roboflow/models/inference.py in predict_video(self, video_path, fps, additional_models, prediction_type)
#     223                     video_data = f.read()
#     224             except Exception as e:
# --> 225                 raise Exception(f"Error reading video: {e}")
#     226
#     227             try:
#
# Exception: Error reading video: [Errno 2] No such file or directory: 'harsh_road.mp4'

# %%
from roboflow import Roboflow
import json

# Initialize Roboflow
rf = Roboflow(api_key="OPMeISeEpQl74oLVReUR")
project = rf.workspace().project("car_-w0bxi")
model = project.version(1).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "/content/drive/MyDrive/Colab Notebooks/vq.mp4",
    fps=1,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['car_-w0bxi']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Feed classes into OpenAI prompt
for class_name in classes:
    prompt = f"""
    Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

    Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

    Use at most 30 words.

    Technical specifications: ```{class_name}```
    """
    response = get_completion(prompt)
    print(response)

# %%
from roboflow import Roboflow
import json

# Initialize Roboflow
rf = Roboflow(api_key="OPMeISeEpQl74oLVReUR")
project = rf.workspace().project("car_-w0bxi")
model = project.version(3).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "/content/drive/MyDrive/Colab Notebooks/vq.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['car_-w0bxi']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Feed classes into OpenAI prompt
response_obtained = False  # Flag to track if response has been obtained
for class_name in classes:
    if response_obtained:
        break  # Exit loop if response has been obtained
    prompt = f"""
    Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

    Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

    Use at most 30 words.

    Technical specifications: ```{class_name}```
    """
    response = get_completion(prompt)
    print(response)
    response_obtained = True  # Set flag to True after obtaining response

# %%
from roboflow import Roboflow
import json
from gtts import gTTS
import os

language = 'en'


# Initialize Roboflow
rf = Roboflow(api_key="qScbRsjfKz4rGJXPM164")
project = rf.workspace().project("smart-driver-assistant-6mw78")
model = project.version(3).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "harsh_road.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['smart-driver-assistant-6mw78']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Feed classes into OpenAI prompt
processed_classes = set()  # Set to store processed classes
for class_name in classes:
    if class_name not in processed_classes:
        prompt = f"""
        Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

        Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

        Use at most 15 words.

        Technical specifications: ```{class_name}```
        """
        response = get_completion(prompt)
        print(response)
        processed_classes.add(class_name)  # Add class to processed set
  # Create a text-to-speech object
        tts = gTTS(text=response, lang=language, slow=False)

# Save the audio output to a file
tts.save("output.mp3")

# %%
from roboflow import Roboflow
import json
from gtts import gTTS

language = 'en'

# Initialize Roboflow
rf = Roboflow(api_key="qScbRsjfKz4rGJXPM164")
project = rf.workspace().project("smart-driver-assistant-6mw78")
model = project.version(3).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "harsh_road.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['smart-driver-assistant-6mw78']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Feed classes into OpenAI prompt
processed_classes = set()  # Set to store processed classes
instructions = {}  # Dictionary to store instructions for each class

for class_name in classes:
    if class_name not in processed_classes:
        prompt = f"""
        Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

        Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

        Use at most 15 words.

        Technical specifications: ```{class_name}```
        """
        response = get_completion(prompt)
        print(response)
        instructions[class_name] = response
        processed_classes.add(class_name)  # Add class to processed set

# Create and save audio files for each instruction
for class_name, instruction in instructions.items():
    tts = gTTS(text=instruction, lang=language, slow=False)
    audio_file = f"{class_name}.mp3"
    tts.save(audio_file)
    print(f"Audio file saved for {class_name}: {audio_file}")

# %%
# !pip install pydub

# %%
from roboflow import Roboflow
import json
from gtts import gTTS
from pydub import AudioSegment

language = 'en'

# Initialize Roboflow
rf = Roboflow(api_key="qScbRsjfKz4rGJXPM164")
project = rf.workspace().project("smart-driver-assistant-6mw78")
model = project.version(3).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "harsh_road.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['smart-driver-assistant-6mw78']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Feed classes into OpenAI prompt
processed_classes = set()  # Set to store processed classes
instructions = {}  # Dictionary to store instructions for each class

for class_name in classes:
    if class_name not in processed_classes:
        prompt = f"""
        Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

        Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

        Use at most 15 words.

        Technical specifications: ```{class_name}```
        """
        response = get_completion(prompt)
        print(response)
        instructions[class_name] = response
        processed_classes.add(class_name)  # Add class to processed set

# Combine all audio files into one
combined_audio = None
for class_name, instruction in instructions.items():
    tts = gTTS(text=instruction, lang=language, slow=False)
    audio_file = f"{class_name}.mp3"
    tts.save(audio_file)
    print(f"Audio file saved for {class_name}: {audio_file}")

    audio_segment = AudioSegment.from_mp3(audio_file)
    if combined_audio is None:
        combined_audio = audio_segment
    else:
        combined_audio += audio_segment

# Export the combined audio to a file
combined_audio.export("combined_audio.mp3", format="mp3")
print("Combined audio file saved: combined_audio.mp3")

# %%
import json

# Sample JSON data representing road safety rules
road_safety_rules_json = '''
{
    "rules": [
        {
            "id": 1,
            "title": "Wearing Seatbelts",

        },
        {
            "id": 2,
            "title": "Speed Limits",

        },
        {
            "id": 3,
            "title": "Using Turn Signals",

        }
    ]
}

'''



# Accessing road safety rules
road_safety_rules = parsed_data["rules"]



# Displaying road safety rules
for rule in road_safety_rules:
   data=rule["title"]
    # Create input for OpenAI prompt
   prompt = f"""
Your task is to direct and give instructions to a driver as there is a {data} approaching ahead.

Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

Use at most 30 words.

Technical specifications: ```{data}```
"""

# Get OpenAI completion
response = get_completion(prompt)
print(response)

# %%
from roboflow import Roboflow
import json
from gtts import gTTS
from playsound import playsound

language = 'en'

# Initialize Roboflow
rf = Roboflow(api_key="OPMeISeEpQl74oLVReUR")
project = rf.workspace().project("car_-w0bxi")
model = project.version(1).model

# Define the class you want to trigger the loud sound
trigger_class = "YourTriggerClassName"

# Predict video
job_id, signed_url, _ = model.predict_video(
    "/content/drive/MyDrive/Colab Notebooks/vq.mp4",
    fps=5,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['car_-w0bxi']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        if class_name == trigger_class:
            # Play a loud sound if the trigger class is detected
            playsound("loud_sound.mp3", block=False)
        classes.append(class_name)

# Feed classes into OpenAI prompt
processed_classes = set()  # Set to store processed classes
instructions = {}  # Dictionary to store instructions for each class

for class_name in classes:
    if class_name not in processed_classes:
        prompt = f"""
        Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

        Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

        Use at most 15 words.

        Technical specifications: ```{class_name}```
        """
        response = get_completion(prompt)
        print(response)
        instructions[class_name] = response
        processed_classes.add(class_name)  # Add class to processed set

# Create and save audio files for each instruction
for class_name, instruction in instructions.items():
    tts = gTTS(text=instruction, lang=language, slow=False)
    audio_file = f"{class_name}.mp3"
    tts.save(audio_file)
    print(f"Audio file saved for {class_name}: {audio_file}")

# %%
! pip install pyttsx3
! pip install gTTS

# %%
from roboflow import Roboflow
from IPython.display import Audio
import json
import pyttsx3
from gtts import gTTS

# Initialize Roboflow
rf = Roboflow(api_key="OPMeISeEpQl74oLVReUR")
project = rf.workspace().project("car_-w0bxi")
model = project.version(1).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "/content/drive/MyDrive/Colab Notebooks/vq.mp4",
    fps=3,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['car_-w0bxi']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Initialize text-to-speech engine

# Initialize an array to store responses
responses_array = []

# Initialize a variable to keep track of the last printed response
last_printed_response = None

# Feed classes into OpenAI prompt
for class_name in classes:
    prompt = f"""
    Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

    Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

    Use at most 5 words.

    Technical specifications: {class_name}
    """
    response = get_completion(prompt)

    # Append the response to the array
    responses_array.append(response)

    # Print the response only if it's different from the last printed response
    if response != last_printed_response:
        print(response)

        last_printed_response = response

# Now responses_array contains all the responses
# You can iterate over it to perform further actions
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Signed URL https://storage.googleapis.com/roboflow_video_inference_input_prod/v8n4a4yHLadhflDu5Kzsk4Azapg2/vq.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=roboflow-platform%40appspot.gserviceaccount.com%2F20240408%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240408T063953Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=content-type%3Bhost&X-Goog-Signature=...
# Checking for video inference results for job 17806fb1-6e7f-4796-bdf8-10acb5e9ec7f every 60s
# (0s): Checking for inference results
# Results {'frame_offset': [0, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232], 'time_offset': [0.0, 0.3333, 0.6667, 1.0, 1.3333, 1.6667, 2.0, 2.3333, 2.6667, 3.0, 3.3333, 3.6667, 4.0, 4.3333, 4.6667, 5.0, 5.3333, 5.6667, 6.0, 6.3333, 6.6667, 7.0, 7.3333, 7.6667, 8.0, 8.3333, 8.6667, 9.0, 9.3333, 9.6667], 'car_-w0bxi': [{'time': 0.1368188876658678, 'image': {'width': 960, 'height': 450}, 'predictions': []}, {'time': 0.13684577494859695, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 166.0, 'y': 311.5, 'width': 288.0, 'height': 277.0, 'confidence': 0.7093136310577393, 'class': 'regulatory_No_stop_or_parking', 'class_id': 90, 'detection_id': '1e646d9c-07d9-4c0d-841f-7e61810a017f'}, {'x': 171.5, 'y': 323.0, 'width': 281.0, 'height': 224.0, 'confidence': 0.5054238438606262, 'class': 'Pedestrian_crossing', 'class_id': 49, 'detection_id': 'dddaf410-6499-41f2-8380-b8330b237a18'}]}, {'time': 0.1368513097986579, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 181.0, 'y': 312.5, 'width': 314.0, 'height': 275.0, 'confidence': 0.6241022348403931, 'class': 'regulatory_No_stop_or_parking', 'class_id': 90, 'detection_id': 'e4f82a99-48b3-408e-9df0-806778797a3f'}, {'x': 185.0, 'y': 324.0, 'width': 292.0, 'height': 224.0, 'confidence': 0.4624853730201721, 'class': 'Pedestrian_crossing', 'class_id': 49, 'detection_id': '3264a536-7e0e-4319-a30d-dae6ba0e047e'}]}, {'time': 0.13685488793998957, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 480.0, 'y': 225.5, 'width': 960.0, 'height': 449.0, 'confidence': 0.450089693069458, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': 'a962d3d6-e788-431d-88e6-b8b1348765cb'}]}, {'time': 0.13987189624458551, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 480.0, 'y': 225.0, 'width': 960.0, 'height': 450.0, 'confidence': 0.4365370273590088, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': 'd4eaa436-2efc-43c3-80ba-eb8abf52b73e'}]}, {'time': 0.13989719934761524, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 480.0, 'y': 225.0, 'width': 960.0, 'height': 450.0, 'confidence': 0.5207889676094055, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': 'a11c5e4a-d29e-4063-b723-a35aa9a44d27'}, {'x': 225.0, 'y': 313.0, 'width': 332.0, 'height': 274.0, 'confidence': 0.47896653413772583, 'class': 'regulatory_No_stop_or_parking', 'class_id': 90, 'detection_id': '11a996f2-70ed-4cbc-b8c0-8506b72a844e'}]}, {'time': 0.1399022750556469, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 480.0, 'y': 228.0, 'width': 960.0, 'height': 444.0, 'confidence': 0.6323628425598145, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': '404055fd-1484-4db9-97fc-e753a509eb0a'}]}, {'time': 0.13990590162575245, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 458.5, 'y': 232.0, 'width': 917.0, 'height': 436.0, 'confidence': 0.6104705929756165, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': '323c0075-09e5-4e01-ae5d-d161710443d0'}]}, {'time': 0.12828661408275366, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 458.0, 'y': 237.0, 'width': 916.0, 'height': 426.0, 'confidence': 0.47152000665664673, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': '91393b6f-8f37-403e-8210-fbc10dc18ede'}]}, {'time': 0.1283118249848485, 'image': {'width': 960, 'height': 450}, 'predictions': [{'x': 480.0, 'y': 238.5, 'width': 960.0, 'height': 423.0, 'confidence': 0.5355267524719238, 'class': 'Indication_for_bicycles_and_pedestrians', 'class_id': 43, 'detection_id': '6c0f3245-ccd6-4807-b9ab-5ddff52ede98'}, {'x': 480.0, 'y': 217.5, 'width': 960.0, 'height': 411.0, 'confidence': 0.464918315410614, 'class': 'regulatory_No_passage', 'class_id': 84, 'detection_id': '5e7ae189-129e-40a3-aa0c-f9a ...
# No stopping or parking ahead.
# Slow down, watch for pedestrians.
# No stopping or parking ahead.
# Slow down, watch for pedestrians.
# Slow down, watch for cyclists.
# No stopping or parking ahead.
# Slow down, watch for pedestrians.
# Slow down, watch for cyclists.
# Turn around, no passage ahead.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Turn around, no passage ahead.
# Approaching regulatory drive slowly ahead.
# Turn around, no passage ahead.
# Slow down, watch for cyclists.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Turn around, no passage ahead.
# Slow down, watch for pedestrians.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Turn around, no passage ahead.
# Drive slowly ahead, follow regulations.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Drive slowly ahead, follow signs.
# Slow down, watch for pedestrians.
# Slow down, watch for cyclists.
# No stopping or parking ahead.
# Slow down, watch for pedestrians.
# Slow down, watch for cyclists.
# Slow down, watch for pedestrians.
# Slow down, watch for cyclists.

# %%
from gtts import gTTS
from IPython.display import Audio
import time

# Iterate over the responses array
for response in responses_array:
    # Generate speech from the response
    tts = gTTS(response)

    # Save the speech as a .wav file
    output_file = 'output.wav'
    tts.save(output_file)

    # Play the audio
    display(Audio(output_file, autoplay=True))

    # Wait for the audio to finish playing
    time.sleep(4)  # Adjust the duration as needed
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-a0a489e2af35> in <cell line: 6>()
#      16
#      17     # Wait for the audio to finish playing
# ---> 18     time.sleep(4)  # Adjust the duration as needed
#
# KeyboardInterrupt:

# %%
from roboflow import Roboflow
from IPython.display import Audio
import json
import pyttsx3
from gtts import gTTS

# Initialize Roboflow
rf = Roboflow(api_key="OPMeISeEpQl74oLVReUR")
project = rf.workspace().project("smart-driver-assistant-7xqd5")
model = project.version(1).model

# Predict video
job_id, signed_url, _ = model.predict_video(
    "/content/drive/MyDrive/Colab Notebooks/v1.mp4",
    fps=3,
    prediction_type="batch-video",
)
print("Signed URL", signed_url)

# Get video results
results = model.poll_until_video_results(job_id)
print("Results", results)

# Extract classes from predictions
classes = []

for frame_data in results['smart-driver-assistant-7xqd5']:
    for prediction in frame_data['predictions']:
        class_name = prediction['class']
        classes.append(class_name)

# Initialize text-to-speech engine

# Initialize an array to store responses
responses_array = []

# Initialize a variable to keep track of the last printed response
last_printed_response = None

# Feed classes into OpenAI prompt
for class_name in classes:
    prompt = f"""
    Your task is to direct and give instructions to a driver as there is a {class_name} approaching ahead.

    Write a description based on the information provided only by not providing extra information in the technical specifications delimited by triple backticks.

    Use at most 5 words.

    Technical specifications: {class_name}
    """
    response = get_completion(prompt)

    # Append the response to the array
    responses_array.append(response)

    # Print the response only if it's different from the last printed response
    if response != last_printed_response:
        print(response)

        last_printed_response = response

# Now responses_array contains all the responses
# You can iterate over it to perform further actions
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Signed URL https://storage.googleapis.com/roboflow_video_inference_input_prod/v8n4a4yHLadhflDu5Kzsk4Azapg2/v1.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=roboflow-platform%40appspot.gserviceaccount.com%2F20240408%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240408T065039Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=content-type%3Bhost&X-Goog-Signature=...
# Checking for video inference results for job 30dd9c38-5469-4960-87e8-deabf7fdb5cf every 60s
# (0s): Checking for inference results
# Results {'frame_offset': [0, 9, 19, 29, 39, 49, 59, 69, 79, 89, 99, 109, 119, 129, 139, 149, 159, 169, 179, 189, 199, 209, 219, 229, 239, 249, 259, 269, 279, 289, 299, 309, 319, 329, 339, 349, 359, 369, 379, 389, 399, 409, 419, 429, 439, 449, 459, 469, 479, 489, 499, 509, 519, 529], 'time_offset': [0.0, 0.3003, 0.634, 0.9676, 1.3013, 1.635, 1.9686, 2.3023, 2.636, 2.9696, 3.3033, 3.637, 3.9706, 4.3043, 4.638, 4.9716, 5.3053, 5.639, 5.9726, 6.3063, 6.64, 6.9736, 7.3073, 7.641, 7.9746, 8.3083, 8.642, 8.9756, 9.3093, 9.643, 9.9766, 10.3103, 10.644, 10.9776, 11.3113, 11.645, 11.9786, 12.3123, 12.646, 12.9796, 13.3133, 13.647, 13.9806, 14.3143, 14.648, 14.9816, 15.3153, 15.649, 15.9826, 16.3163, 16.65, 16.9837, 17.3173, 17.651], 'smart-driver-assistant-7xqd5': [{'time': 0.0839630588889122, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08398993592709303, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.0839957557618618, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 389.5, 'y': 139.0, 'width': 239.0, 'height': 278.0, 'confidence': 0.4064338803291321, 'class': 'drowsiness', 'class_id': 1, 'detection_id': '94ccd61f-43bc-4c7d-be55-60f82682ebd8'}]}, {'time': 0.08399957232177258, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 400.0, 'y': 151.5, 'width': 252.0, 'height': 303.0, 'confidence': 0.42284125089645386, 'class': 'drowsiness', 'class_id': 1, 'detection_id': 'a3eb9458-e554-4dfa-b067-8124071d9950'}]}, {'time': 0.08125051017850637, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 407.5, 'y': 140.0, 'width': 237.0, 'height': 270.0, 'confidence': 0.4647183418273926, 'class': 'drowsiness', 'class_id': 1, 'detection_id': '145bfdaa-fc63-4ec1-9af1-924699e1df64'}]}, {'time': 0.0812768628820777, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08128224406391382, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08128606714308262, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08271391317248344, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 430.5, 'y': 185.0, 'width': 331.0, 'height': 350.0, 'confidence': 0.4858807921409607, 'class': 'drowsiness', 'class_id': 1, 'detection_id': '8c03e6cb-4985-489a-8724-b97739817e65'}]}, {'time': 0.08275818824768066, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 433.5, 'y': 175.0, 'width': 333.0, 'height': 350.0, 'confidence': 0.4662827253341675, 'class': 'drowsiness', 'class_id': 1, 'detection_id': '7f66fafb-0f18-4b40-b6a0-d9705e25dcb1'}]}, {'time': 0.08277405612170696, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 397.0, 'y': 184.0, 'width': 330.0, 'height': 352.0, 'confidence': 0.47947555780410767, 'class': 'yawing', 'class_id': 4, 'detection_id': '042d9e4d-9d03-45fb-9ceb-6898a8a158f7'}]}, {'time': 0.08277807757258415, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08213089499622583, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08215697947889566, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.08216193690896034, 'image': {'width': 640, 'height': 360}, 'predictions': [{'x': 397.5, 'y': 184.0, 'width': 353.0, 'height': 352.0, 'confidence': 0.43116313219070435, 'class': 'yawing', 'class_id': 4, 'detection_id': '413c612f-8981-4d7f-a769-e0a1d5fb24e3'}]}, {'time': 0.08216555137187243, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.07930435612797737, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.07933052070438862, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.07933498919010162, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.07933861203491688, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.09340451192110777, 'image': {'width': 640, 'height': 360}, 'predictions': []}, {'time': 0.093435263261199, 'image': {'width': 640, 'heig ...
# Stay alert, pull over soon.
# Slow down, pull over soon.
# Pull over, rest immediately.
# Driver, pull over immediately.
# Prepare to steer carefully. Slow down.
# Slow down, steer carefully ahead.
# Slow down, pull over soon.
# Stay alert, pull over soon.
# Pull over, rest immediately.
# Stay alert, pull over soon.
# Prepare to steer carefully. Slow down.
# Pull over, rest immediately.
# Prepare to steer carefully. Slow down.
# Pull over, rest immediately.
# Stay alert, pull over soon.

# %%
from gtts import gTTS
from IPython.display import Audio
import time

# Iterate over the responses array
for response in responses_array:
    # Generate speech from the response
    tts = gTTS(response)

    # Save the speech as a .wav file
    output_file = 'output.wav'
    tts.save(output_file)

    # Play the audio
    display(Audio(output_file, autoplay=True))

    # Wait for the audio to finish playing
    time.sleep(4)  # Adjust the duration as needed
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-a0a489e2af35> in <cell line: 6>()
#      16
#      17     # Wait for the audio to finish playing
# ---> 18     time.sleep(4)  # Adjust the duration as needed
#
# KeyboardInterrupt:
